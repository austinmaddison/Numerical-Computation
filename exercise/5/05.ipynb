# %%
# %matplotlib inline
import numpy as np
import math
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1D Gradient Descent

# %% [markdown]
# 1) Let us consider the function
# $$ f(x) = (x-2)^2 + 1 $$
# First plot it.

# %%
def f(x):
    return (x-2)**2 + 1
xs = np.linspace(-4, 4)
plt.plot(xs, f(xs))

# %% [markdown]
# 2) If we start at $x=4$, which way should we move and why?

# %% [markdown]
# 3)If the step size is constants = 1.1, what does the update rule look like?
#
# $$x_{n+1} = \ldots$$

# %% [markdown]
# 4)Let try it with step size = 1.1. For 10 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
def grad(f, x0, n, h, step_size):
    guess = x0
    guesses = []
    for i in range(n):
        fp = (f(guess+h) - f(guess-h))/(2*h)
        guess = guess - step_size*fp/abs(fp)
        print(guess)
        guesses.append(guess)
    return guess, np.array(guesses)

guess, guesses = grad(f, x0=4.0, n=10, h=0.0001, step_size=1.1)

plt.plot(xs, f(xs))
plt.plot(guesses, f(guesses), 'or')
# Out:
# 2.9
# 1.7999999999999998
# 2.9
# 1.7999999999999998
# 2.9
# 1.7999999999999998
# 2.9
# 1.7999999999999998
# 2.9
# 1.7999999999999998

# %% [markdown]
# 5)Now let's try step size=0.01 for 100 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
guess, guesses = grad(f, x0=4.0, n=100, h=0.0001, step_size=0.01)

plt.plot(xs, f(xs))
plt.plot(guesses, f(guesses), 'or')
# Out:
# 3.99
# 3.9800000000000004
# 3.9700000000000006
# 3.960000000000001
# 3.950000000000001
# 3.9400000000000013
# 3.9300000000000015
# 3.9200000000000017
# 3.910000000000002
# 3.900000000000002
# 3.8900000000000023
# 3.8800000000000026
# 3.8700000000000028
# 3.860000000000003
# 3.850000000000003
# 3.8400000000000034
# 3.8300000000000036
# 3.820000000000004
# 3.810000000000004
# 3.8000000000000043
# 3.7900000000000045
# 3.7800000000000047
# 3.770000000000005
# 3.760000000000005
# 3.7500000000000053
# 3.7400000000000055
# 3.7300000000000058
# 3.720000000000006
# 3.710000000000006
# 3.7000000000000064
# 3.6900000000000066
# 3.680000000000007
# 3.670000000000007
# 3.6600000000000072
# 3.6500000000000075
# 3.6400000000000077
# 3.630000000000008
# 3.620000000000008
# 3.6100000000000083
# 3.6000000000000085
# 3.5900000000000087
# 3.580000000000009
# 3.570000000000009
# 3.5600000000000094
# 3.5500000000000096
# 3.54000000000001
# 3.53000000000001
# 3.5200000000000102
# 3.5100000000000104
# 3.5000000000000107
# 3.490000000000011
# 3.480000000000011
# 3.4700000000000113
# 3.4600000000000115
# 3.4500000000000117
# 3.440000000000012
# 3.430000000000012
# 3.4200000000000124
# 3.4100000000000126
# 3.400000000000013
# 3.390000000000013
# 3.380000000000013
# 3.3700000000000134
# 3.3600000000000136
# 3.350000000000014
# 3.340000000000014
# 3.3300000000000143
# 3.3200000000000145
# 3.3100000000000147
# 3.300000000000015
# 3.290000000000015
# 3.2800000000000153
# 3.2700000000000156
# 3.2600000000000158
# 3.250000000000016
# 3.240000000000016
# 3.2300000000000164
# 3.2200000000000166
# 3.210000000000017
# 3.200000000000017
# 3.1900000000000173
# 3.1800000000000175
# 3.1700000000000177
# 3.160000000000018
# 3.150000000000018
# 3.1400000000000183
# 3.1300000000000185
# 3.1200000000000188
# 3.110000000000019
# 3.100000000000019
# 3.0900000000000194
# 3.0800000000000196
# 3.07000000000002
# 3.06000000000002
# 3.0500000000000203
# 3.0400000000000205
# 3.0300000000000207
# 3.020000000000021
# 3.010000000000021
# 3.0000000000000213

# %% [markdown]
# 6) When do we want the step size to be small and when do you want the step size to be big?

# %% [markdown]
# 7) What function kind of does that?

# %% [markdown]
# 8)If we use that function, what does the update rule looks like.

# %%
def grad(f, x0, n, h, lmd):
    guess = x0
    guesses = []
    for i in range(n):
        fp = (f(guess+h) - f(guess-h))/(2*h)
        guess = guess - lmd*fp
        guesses.append(guess)
        print(f(guess))
    return guess, np.array(guesses)

# %% [markdown]
# 9) Try it with $\lambda=0.1$. Print and Plot to see what happens?

# %%
guess, guesses = grad(f, x0=4.0, n=100, h=0.0001, lmd=0.1)

plt.plot(xs, f(xs))
plt.plot(guesses, f(guesses), 'o-r')
# Out:
# 3.600000000000044
# 3.279999999999502
# 3.023999999999024
# 2.819199999998908
# 2.6553599999987707
# 2.5242879999988164
# 2.4194303999988085
# 2.3355443199988244
# 2.2684354559989703
# 2.214748364799065
# 2.1717986918391405
# 2.13743895347129
# 2.1099511627770093
# 2.0879609302215627
# 2.0703687441773164
# 2.056294995341764
# 2.0450359962733664
# 2.0360287970186928
# 2.028823037614865
# 2.0230584300918695
# 2.018446744073473
# 2.0147573952588003
# 2.0118059162069732
# 2.0094447329654894
# 2.0075557863723468
# 2.0060446290979215
# 2.004835703278359
# 2.003868562622687
# 2.0030948500980825
# 2.002475880078399
# 2.0019807040627633
# 2.001584563250277
# 2.0012676506002656
# 2.0010141204802565
# 2.0008112963841826
# 2.000649037107279
# 2.0005192296858008
# 2.000415383748618
# 2.0003323069989163
# 2.0002658455990883
# 2.0002126764792036
# 2.0001701411833626
# 2.0001361129466897
# 2.000108890357396
# 2.0000871122859385
# 2.000069689828684
# 2.0000557518629023
# 2.000044601490277
# 2.0000356811922213
# 2.0000285449537323
# 2.0000228359628967
# 2.0000182687702726
# 2.0000146150161955
# 2.0000116920129116
# 2.000009353610329
# 2.000007482888196
# 2.0000059863105566
# 2.0000047890484893
# 2.000003831238769
# 2.000003064991037
# 2.0000024519928292
# 2.0000019615942186
# 2.0000015692753745
# 2.0000012554202105
# 2.000001004336168
# 2.0000008034688452
# 2.0000006427750536
# 2.000000514220109
# 2.0000004113761536
# 2.000000329100967
# 2.0000002632807288
# 2.000000210624516
# 2.000000168499546
# 2.000000134799614
# 2.0000001078396243
# 2.0000000862716547
# 2.0000000690173456
# 2.0000000552138317
# 2.0000000441711094
# 2.000000035336843
# 2.000000028269496
# 2.0000000226155743
# 2.0000000180924147
# 2.000000014473976
# 2.0000000115791803
# 2.000000009263366
# 2.000000007410737
# 2.000000005928589
-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# 1.3657290675666469e-21
# (1.3657290675666469e-21, 0.7390851331930792)

# %% [markdown]
# ### Multi-Dimension Gradient Descent

# %% [markdown]
# 1) Let us consider the function.
# $$f(x,y) = (x-2)^2 + xy + y^2 + 1$$
# Make the 3D plot.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#see matplotlib3d surface
def f(x,y):
    return (x-2)**2+x*y+y**2+1
nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))
for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]
        
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.gca().view_init(elev=15., azim=30)
ucs = ax.plot_surface(xgrid, ygrid, uz, cmap=cm.coolwarm)
plt.title('f(x,y)')
# Out:
# Text(0.5, 0.92, 'f(x,y)')

# %% [markdown]
# 2) Plot the contour.

# %%
from matplotlib import cm
#see http://matplotlib.org/examples/pylab_examples/contour_demo.html
def f(x,y):
    return (x-2)**2+x*y+y**2+1

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')
# Out:
# Text(0.5, 1.0, 'f(x,y)')

# %% [markdown]
# 3)Where do you think the minimum is?

# %% [markdown]
# 4)What is the gradient at (10,-15)? Use plt.arrow to plot arrow.

# %% [markdown]
# 5) If we want to minimize the function which way should we go? Find the unit vector in that direction.

# %% [markdown]
# 6) What should your update rule look like? Use vector addition.

# %% [markdown]
# 7) Use what we learn in 1D. How far should we go? What should the update rule really look like?

# %% [markdown]
# 8) Use $\lambda = 0.1$ and see where the points go

# %%
def f(r):
    x, y = r
    return (x-2)**2+x*y+y**2+1
    
def gradient(f, r, h):
    dx = (f(r+[h, 0]) - f(r-[h, 0]))/2/h
    dy = (f(r+[0, h]) - f(r-[0, h]))/2/h
    return np.array([dx, dy])

def grad(f, r0, lmd, n, h):
    r = r0.copy()
    guesses = []
    for i in range(n):
        r = r - lmd * gradient(f, r, h)
        guesses.append(r.copy())
    return r, guesses

# %%
r, guesses = grad(f, np.array([15., 10.]), 0.1, 100, h=0.01)

from matplotlib import cm
#see http://matplotlib.org/examples/pylab_examples/contour_demo.html
def f(x,y):
    return (x-2)**2+x*y+y**2+1

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')

for guess in guesses:
    x, y = guess
    plt.plot(x, y, 'o')

# %% [markdown]
# ### Linear Regression Revisited

# %% [markdown]
# Let us consider the problem of findind a line that pass through the points.

# %%
np.random.seed(123)
n = 100
dx = np.linspace(0,1,n)
dy = -2*dx + 1 + np.random.randn(n)/2
plt.plot(dx,dy,'.r')

# %% [markdown]
# 1) What exactly are we trying to minimize and why?

# %%
def f(r):
    m, c = r
    #print(sum((m*dx + c - dy)**2))
    return sum((m*dx + c - dy)**2)
r, _ = grad(f, np.array([0.,0.]), 0.001, 1000, h=0.001)

# find m ,c for me.
plt.plot(dx,dy,'.r')
m, c = r
plt.plot(dx, m*dx + c)

from scipy.optimize import minimize

res = minimize(f, np.array([0.,0.]))
print (res)
m, c = res.x
# find m ,c for me.
plt.figure()
plt.plot(dx,dy,'.r')
m, c = r
plt.plot(dx, m*dx + c)
# Out:
#       fun: 31.82148958777588
#  hess_inv: array([[ 0.05889646, -0.0294361 ],
#        [-0.0294361 ,  0.01971372]])
#       jac: array([4.76837158e-07, 7.15255737e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 24
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([-1.98596612,  1.00653759])

# %% [markdown]
# 2) Minimize and Visualize it.

# %% [markdown]
# ### Separating Line.

# %% [markdown]
# We want to draw a separating line betwen two datasets shown below.

# %%
np.random.seed(234)
n1 = 100
n2 = 100
mean = [0, 0]
cov = [[1, -0.5], [-0.5, 1]]
r1, r2 = np.random.multivariate_normal(mean, cov, n1).T
#plt.plot(r1, r2, '.r')

mean = [2, 2]
cov = [[1, 0], [0, 1]]
b1, b2 = np.random.multivariate_normal(mean, cov, n2).T
#plt.plot(b1, b2, '.b')

c = np.zeros(n1+n2)
c[:n1] = 1.
c[n1:] = 0.
#print c
colors = c

d = np.zeros((n1+n2,2))
d[:n1,0] = r1
d[:n1,1] = r2
d[n1:,0] = b1
d[n1:,1] = b2

# %%
plt.plot(d[c==1,0], d[c==1,1],'.r')#note boolean indexing
plt.plot(d[c==0,0], d[c==0,1],'.b')#note boolean indexing

# %% [markdown]
# 1) How can we model this as a optimization problem?

# %%
def on_the_wrong_side(x, y, color, m, c):
    if color==1: # red should be below
        return y > m*x + c
    else: # blue should be above
        return y < m*x + c

def f(r):
    m, c = r
    cost = 0
    for (x, y), color in zip(d, colors):
        if on_the_wrong_side(x, y, color, m, c):
            cost += (m*x + c - y)**2
    return cost

m, c = minimize(f, np.array([0,0])).x

# %%
plt.plot(d[colors==1,0], d[colors==1,1],'.r')#note boolean indexing
plt.plot(d[colors==0,0], d[colors==0,1],'.b')#note boolean indexing

xs = np.linspace(-2, 5, 100)
plt.plot(xs, m*xs + c)
